# %%
#authored by Tim (taken from 3/17/24)

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /home/zebalgebra/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages (4.38.2)
# Requirement already satisfied: filelock in /home/zebalgebra/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /home/zebalgebra/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages (from transformers) (0.21.4)
# Requirement already satisfied: numpy>=1.17 in /home/zebalgebra/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/zebalgebra/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/zebalgebra/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/zebalgebra/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /home/zebalgebra/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/zebalgebra/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /home/zebalgebra/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /home/zebalgebra/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/zebalgebra/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/zebalgebra/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/zebalgebra/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/zebalgebra/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zebalgebra/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zebalgebra/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages (from requests->transformers) (2024.2.2)

# %%
import torch
import transformers as ppb
import pandas as pd
import numpy as np

# %% [markdown]
# # Install and init BERT model.

# %%
model_class, tokenizer_class, pretrained_weights = (ppb.BertModel, ppb.BertTokenizer, 'bert-base-uncased')

# Load pretrained model/tokenizer
tokenizer = tokenizer_class.from_pretrained(pretrained_weights)
model = model_class.from_pretrained(pretrained_weights)

# %% [markdown]
# # Process Inputs

# %%
import pandas as pd
from ast import literal_eval

books_df = pd.read_csv('https://raw.githubusercontent.com/malcolmosh/goodbooks-10k/master/books_enriched.csv', index_col=[0], converters={"genres": literal_eval})
books_df = books_df[:1000]

# %%
books_df['short_description'] = books_df.description.str.slice(0,512)

# %%
# TODO 1: @Swathi read the dataset from a Bucket or Google Drive
df = books_df.short_description

# %%
tokenized = df.apply((lambda x: tokenizer.encode(str(x), add_special_tokens=True)))

# %%
max_len = 0
for i in tokenized.values:
    if len(i) > max_len:
        max_len = len(i)

padded = np.array([i + [0]*(max_len-len(i)) for i in tokenized.values])
attention_mask = np.where(padded != 0, 1, 0)

# %% [markdown]
# # Embed Text

# %%
device = torch.device('cuda')

torch.cuda.set_per_process_memory_fraction(0.70, torch.cuda.device(0))

input_ids = torch.tensor(padded).to(device)
attention_mask = torch.tensor(attention_mask).to(device)
model = model.to(device)

with torch.no_grad():
    last_hidden_states = model(input_ids, attention_mask=attention_mask)
# Out:
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[9], line 10
#       7 model = model.to(device)
#       9 with torch.no_grad():
# ---> 10     last_hidden_states = model(input_ids, attention_mask=attention_mask)
#
# File ~/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:1006, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     999 # Prepare head mask if needed
#    1000 # 1.0 in head_mask indicate we keep the head
#    1001 # attention_probs has shape bsz x n_heads x N x N
#    1002 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#    1003 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#    1004 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# -> 1006 embedding_output = self.embeddings(
#    1007     input_ids=input_ids,
#    1008     position_ids=position_ids,
#    1009     token_type_ids=token_type_ids,
#    1010     inputs_embeds=inputs_embeds,
#    1011     past_key_values_length=past_key_values_length,
#    1012 )
#    1013 encoder_outputs = self.encoder(
#    1014     embedding_output,
#    1015     attention_mask=extended_attention_mask,
#    (...)
#    1023     return_dict=return_dict,
#    1024 )
#    1025 sequence_output = encoder_outputs[0]
#
# File ~/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages/transformers/models/bert/modeling_bert.py:233, in BertEmbeddings.forward(self, input_ids, token_type_ids, position_ids, inputs_embeds, past_key_values_length)
#     231 if inputs_embeds is None:
#     232     inputs_embeds = self.word_embeddings(input_ids)
# --> 233 token_type_embeddings = self.token_type_embeddings(token_type_ids)
#     235 embeddings = inputs_embeds + token_type_embeddings
#     236 if self.position_embedding_type == "absolute":
#
# File ~/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages/torch/nn/modules/sparse.py:163, in Embedding.forward(self, input)
#     162 def forward(self, input: Tensor) -> Tensor:
# --> 163     return F.embedding(
#     164         input, self.weight, self.padding_idx, self.max_norm,
#     165         self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# File ~/School/DVA/The-Last-Book-Bender/.venv/lib/python3.11/site-packages/torch/nn/functional.py:2237, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2231     # Note [embedding_renorm set_grad_enabled]
#    2232     # XXX: equivalent to
#    2233     # with torch.no_grad():
#    2234     #   torch.embedding_renorm_
#    2235     # remove once script supports set_grad_enabled
#    2236     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2237 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 504.00 MiB. GPU 0 has a total capacity of 1.95 GiB of which 973.62 MiB is free. Including non-PyTorch memory, this process has 1014.00 MiB memory in use. Of the allocated memory 927.64 MiB is allocated by PyTorch, and 50.36 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
embeddings = last_hidden_states[0].cpu().data[:,0,:].numpy()

# %%
df.shape, embeddings.shape
# Out:
# ((1000,), (1000, 768))

# %% [markdown]
# # Save Embeddings

# %%
embeddings_pd_df = pd.DataFrame({'book_id': range(df.shape[0])})
embeddings_pd_df['title'] = books_df['title']
embeddings_pd_df['embedding'] = embeddings.tolist()

# %%
# TODO 2: @Swathi save embeddings_pd_df to another bucket in JSON format
embeddings_pd_df['embedding'] = embeddings_pd_df['embedding'].apply(lambda x: np.array(x))

# %%
embeddings_pd_df.head()
# Out:
#    book_id                                              title  \
# 0        0            The Hunger Games (The Hunger Games, #1)
# 1        1  Harry Potter and the Sorcerer's Stone (Harry P...
# 2        2                            Twilight (Twilight, #1)
# 3        3                              To Kill a Mockingbird
# 4        4                                   The Great Gatsby
#
#                                            embedding
# 0  [0.11946984380483627, 0.057541050016880035, 0....
# 1  [-0.3747820258140564, -0.2721218168735504, 0.1...
# 2  [0.12502743303775787, -0.7245563268661499, -0....
# 3  [-0.4378758668899536, -0.29153937101364136, -0...
# 4  [-0.4059891104698181, -0.47040677070617676, -0...

# %% [markdown]
# # Train KNN

# %%
from sklearn.neighbors import NearestNeighbors

X = np.array(embeddings_pd_df['embedding'].values.tolist())
k = 5
nn_model = NearestNeighbors(n_neighbors=k, algorithm='ball_tree').fit(X)

# %% [markdown]
# # Query KNN

# %%
query = np.array([X[i] + np.random.normal(loc=0.0, scale=1.0, size=X[0].shape) for i in range(2)])

# %%
distances, indices = nn_model.kneighbors(query)

# %%
i = 0
for book_rec in indices:
    i += 1
    j = 0
    print(f"Top {k} recommendations for query {i}:")
    for index in book_rec:
        j += 1
        print(f"\t{j}. {embeddings_pd_df.iloc[index]['title']}")
# Out:
# Top 5 recommendations for query 1:
# 	1. The Hunger Games (The Hunger Games, #1)
# 	2. Graceling (Graceling Realm, #1)
# 	3. The Client
# 	4. The Pelican Brief
# 	5. A Court of Thorns and Roses (A Court of Thorns and Roses, #1)
# Top 5 recommendations for query 2:
# 	1. Harry Potter and the Sorcerer's Stone (Harry Potter, #1)
# 	2. A Discovery of Witches (All Souls Trilogy, #1)
# 	3. The Iron King (The Iron Fey, #1)
# 	4. City of Heavenly Fire (The Mortal Instruments, #6)
# 	5. Fruits Basket, Vol. 1
